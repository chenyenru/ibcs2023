# %% [markdown]
# # Standard Text Adventure

# %% [markdown]
# ## In-Class

# %%
def user_input(prompt: str) -> int:
    try:
        return int(input(prompt))
    except (ValueError, TypeError):
        return -1
    
def volume():
    print("""
    You ignored the notorious serial killer. She comes into your room and murders you
    """)


def listen():
    print("""
    You listen carefully to the sounds in your house.
    After a few minutes you hear a strange noise coming from the other room.
    You believe someone is moving in that room.

    What do you want to do?

        1. Lock your door
        2. Investigate the noise
        3. Turn the volume even louder
    """)

    choice = -1
    while choice < 1 or choice > 3:
        choice = user_input("Make a choice:")

        if choice == 1:
            lockdoor()
        elif choice == 2:
            investigate()
        elif choice == 3:
            volume()


def investigate():
    print("""
   You walk into the other room and find a notorious serial killer. She kills you and eats your eyeballs and pees.

   The end 😀 
    """)


def lockdoor():
    print("""
    You lock the door and keep out the notorious serial killer.
    She is thwarted by your super strong lock.

    You live, the end.
    """)



def start():
    print(
        """
        It's a dark and stormy night and you believe you're home alone.
        You are sitting on your bed watching Youtube videos.
        You hear a sound coming from the other room.
        What do you do?

            1. Turn up the volume
            2. Listen carefully for the sound
            3. Investigate the sound
        """
    )
    choice = -1
    while (choice < 1 or choice > 3):
        choice = user_input("make a choice")

        if choice == 1:
            volume()
        elif choice == 2:
            listen()
        elif choice == 3:
            investigate()
        else:
            print("Please choose 1, 2, or 3")


if __name__ == '__main__':
    start()
# Out:
#         It's a dark and stormy night and you believe you're home alone.
#         You are sitting on your bed watching Youtube videos.
#         You hear a sound coming from the other room.
#         What do you do?
#
#             1. Turn up the volume
#             2. Listen carefully for the sound
#             3. Investigate the sound
#
#
#     You listen carefully to the sounds in your house.
#     After a few minutes you hear a strange noise coming from the other room.
#     You believe someone is moving in that room.
#
#     What do you want to do?
#
#         1. Lock your door
#         2. Investigate the noise
#         3. Turn the volume even louder
#
#
#     You lock the door and keep out the notorious serial killer.
#     She is thwarted by your super strong lock.
#
#     You live, the end.

# %% [markdown]
# ## My own

# %%
def user_input(prompt: str) -> int:
    try:
        return int(input(prompt))
    except (ValueError, TypeError):
        return -1
    
def date():
    print("""
    You ignored the notorious serial killer. She comes into your room and murders you
    """)


def cookie():
    print("""
    You listen carefully to the sounds in your house.
    After a few minutes you hear a strange noise coming from the other room.
    You believe someone is moving in that room.

    What do you want to do?

        1. Lock your door
        2. Investigate the noise
        3. Turn the volume even louder
    """)

    choice = -1
    while choice < 1 or choice > 3:
        choice = user_input("Make a choice:")

        if choice == 1:
            lockdoor()
        elif choice == 2:
            investigate()
        elif choice == 3:
            volume()


def sleep():
    print("""
   You slept the day, and today is your physics summative.

   You're dead.
   The end.
    """)


def lockdoor():
    print("""
    You lock the door and keep out the notorious serial killer.
    She is thwarted by your super strong lock.

    You live, the end.
    """)



def start():
    print(
        """
        It's a perfect morning. 
        Sunshine in your face,
        Leaving you it's pretty grace, 
        Of it's love so warm. 
        Sunshine in your head, 
        Making you think of your friends,
        Of it's love so darn.

        Oh what a sunny day! It's a perfect day to 

            1. Call your date and have a date
            2. Browse cookie recipes and try them all
            3. Coil back in bed and sleep the day
        """

        if choice == 1:
            date()
        elif choice == 2:
            cookie()
        elif choice == 3:
            sleep()
        else:
            print("Please choose 1, 2, or 3")

    )
    choice = -1
    while (choice < 1 or choice > 3):
        choice = user_input("make a choice")

        if choice == 1:
            date()
        elif choice == 2:
            cookie()
        elif choice == 3:
            sleep()
        else:
            print("Please choose 1, 2, or 3")


if __name__ == '__main__':
    start()
